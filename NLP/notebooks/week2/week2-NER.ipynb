# %% [markdown]
# # Recognize named entities on Twitter with LSTMs
#
# In this assignment, you will use a recurrent neural network to solve Named Entity Recognition (NER) problem. NER is a common task in natural language processing systems. It serves for extraction such entities from the text as persons, organizations, locations, etc. In this task you will experiment to recognize named entities from Twitter.
#
# For example, we want to extract persons' and organizations' names from the text. Than for the input text:
#
#     Ian Goodfellow works for Google Brain
#
# a NER model needs to provide the following sequence of tags:
#
#     B-PER I-PER    O     O   B-ORG  I-ORG
#
# Where *B-* and *I-* prefixes stand for the beginning and inside of the entity, while *O* stands for out of tag or no tag. Markup with the prefix scheme is called *BIO markup*. This markup is introduced for distinguishing of consequent entities with similar types.
#
# A solution of the task will be based on neural networks, particularly, on Bi-Directional Long Short-Term Memory Networks (Bi-LSTMs).

# %% [markdown]
# ### Data
#
# The following cell will download all data required for this assignment into the folder `week2/data`.

# %%
import sys
sys.path.append("..")
from download_utils import download_week2_resources

download_week2_resources()
# Out:
# File data/train.txt is already downloaded.
# File data/validation.txt is already downloaded.
# File data/test.txt is already downloaded.

# %% [markdown]
# ### Load the Twitter Named Entity Recognition corpus
#
# We will work with a corpus, which contains tweets with NE tags. Every line of a file contains a pair of a token (word/punctuation symbol) and a tag, separated by a whitespace. Different tweets are separated by an empty line.
#
# The function *read_data* reads a corpus from the *file_path* and returns two lists: one with tokens and one with the corresponding tags. You need to complete this function by adding a code, which will replace a user's nickname to `<USR>` token and any URL to `<URL>` token. You could think that a URL and a nickname are just strings which start with *http://* or *https://* in case of URLs and a *@* symbol for nicknames.

# %%
import re

def read_data(file_path):
    tokens = []
    tags = []
    
    tweet_tokens = []
    tweet_tags = []
    for line in open(file_path, encoding='utf-8'):
        line = line.strip()
        if not line:
            if tweet_tokens:
                tokens.append(tweet_tokens)
                tags.append(tweet_tags)
            tweet_tokens = []
            tweet_tags = []
        else:
            token, tag = line.split()
            # Replace all urls with <URL> token
            # Replace all users with <USR> token
            if token.startswith(('http', 'https', 'ftp')):
                token = '<URL>'
            if token.startswith('@'):
                token = '<USER>'
            tweet_tokens.append(token)
            tweet_tags.append(tag)
            
    return tokens, tags

# %% [markdown]
# And now we can load three separate parts of the dataset:
#  - *train* data for training the model;
#  - *validation* data for evaluation and hyperparameters tuning;
#  - *test* data for final evaluation of the model.

# %%
train_tokens, train_tags = read_data('data/train.txt')
validation_tokens, validation_tags = read_data('data/validation.txt')
test_tokens, test_tags = read_data('data/test.txt')

# %%
train_tokens[:10]
# Out:
# [['RT',
#   '<USER>',
#   ':',
#   'Online',
#   'ticket',
#   'sales',
#   'for',
#   'Ghostland',
#   'Observatory',
#   'extended',
#   'until',
#   '6',
#   'PM',
#   'EST',
#   'due',
#   'to',
#   'high',
#   'demand',
#   '.',
#   'Get',
#   'them',
#   'before',
#   'they',
#   'sell',
#   'out',
#   '...'],
#  ['Apple',
#   'MacBook',
#   'Pro',
#   'A1278',
#   '13.3',
#   '"',
#   'Laptop',
#   '-',
#   'MD101LL/A',
#   '(',
#   'June',
#   ',',
#   '2012',
#   ')',
#   '-',
#   'Full',
#   'read',
#   'by',
#   'eBay',
#   '<URL>',
#   '<URL>'],
#  ['Happy',
#   'Birthday',
#   '<USER>',
#   '!',
#   'May',
#   'Allah',
#   's.w.t',
#   'bless',
#   'you',
#   'with',
#   'goodness',
#   'and',
#   'happiness',
#   '.'],
#  ['<USER>',
#   'the',
#   'quest',
#   'line',
#   'im',
#   'assuming',
#   'it',
#   'will',
#   'be',
#   'the',
#   'same',
#   'way',
#   'with',
#   'awe',
#   'thur'],
#  ['<USER>',
#   '<USER>',
#   '<USER>',
#   '<USER>',
#   '<USER>',
#   'still',
#   'perception',
#   ',',
#   'and',
#   'what',
#   'you',
#   'key',
#   'off',
#   'may',
#   'differ',
#   'from',
#   'me',
#   '.',
#   'Back',
#   'to',
#   'Selma',
#   'example',
#   ',',
#   'iow',
#   '.'],
#  ['Amazon',
#   'Kindle',
#   'Fire',
#   '1st',
#   'Generation',
#   '8GB',
#   ',',
#   'Wi-Fi',
#   ',',
#   '7in',
#   '-',
#   'Black',
#   '-',
#   'Full',
#   'read',
#   'by',
#   'eBay',
#   '<URL>',
#   '<URL>'],
#  ['<USER>', "I'll", 'call', 'u', 'after', 'class', 'pooky', ';D'],
#  ['TL_jp', 'August', '29', ',', '2015', 'at', '01:25', 'AM', '<URL>'],
#  ['<USER>',
#   'Wie',
#   'staat',
#   'daar',
#   'nou',
#   'met',
#   'de',
#   'microfoon',
#   'links',
#   ';-)',
#   '<URL>'],
#  ['Why', 'do', 'I', 'have', 'an', 'exam', 'tomorrow', 'morning', '?']]

# %% [markdown]
# You should always understand what kind of data you deal with. For this purpose, you can print the data running the following cell:

# %%
for i in range(3):
    for token, tag in zip(train_tokens[i], train_tags[i]):
        print('%s\t%s' % (token, tag))
    print()
# Out:
# RT	O
# <USER>	O
# :	O
# Online	O
# ticket	O
# sales	O
# for	O
# Ghostland	B-musicartist
# Observatory	I-musicartist
# extended	O
# until	O
# 6	O
# PM	O
# EST	O
# due	O
# to	O
# high	O
# demand	O
# .	O
# Get	O
# them	O
# before	O
# they	O
# sell	O
# out	O
# ...	O
#
# Apple	B-product
# MacBook	I-product
# Pro	I-product
# A1278	I-product
# 13.3	I-product
# "	I-product
# Laptop	I-product
# -	I-product
# MD101LL/A	I-product
# (	O
# June	O
# ,	O
# 2012	O
# )	O
# -	O
# Full	O
# read	O
# by	O
# eBay	B-company
# <URL>	O
# <URL>	O
#
# Happy	O
# Birthday	O
# <USER>	O
# !	O
# May	O
# Allah	B-person
# s.w.t	O
# bless	O
# you	O
# with	O
# goodness	O
# and	O
# happiness	O
# .	O

# %% [markdown]
# ### Prepare dictionaries
#
# To train a neural network, we will use two mappings:
# - {token}$\to${token id}: address the row in embeddings matrix for the current token;
# - {tag}$\to${tag id}: one-hot ground truth probability distribution vectors for computing the loss at the output of the network.
#
# Now you need to implement the function *build_dict* which will return {token or tag}$\to${index} and vice versa.

# %%
from collections import defaultdict

# %%
def build_dict(tokens_or_tags, special_tokens):
    """
        tokens_or_tags: a list of lists of tokens or tags
        special_tokens: some special tokens
    """
    # Create a dictionary with default value 0
    tok2idx = defaultdict(lambda: 0)
    idx2tok = []
    
    # Create mappings from tokens (or tags) to indices and vice versa.
    # At first, add special tokens (or tags) to the dictionaries.
    # The first special token must have index 0.
    flattened_tokens_or_tags = [word for sentence in tokens_or_tags for word in sentence]
    unk_token = special_tokens[0]
    tokens_or_tags_set = [unk_token] + list(set(flattened_tokens_or_tags)|set(special_tokens) - set([unk_token]))
    # Mapping tok2idx should contain each token or tag only once. 
    # To do so, you should:
    # 1. extract unique tokens/tags from the tokens_or_tags variable, which is not
    #    occur in special_tokens (because they could have non-empty intersection)
    # 2. index them (for example, you can add them into the list idx2tok
    # 3. for each token/tag save the index into tok2idx).
    tok2idx = {tok:idx for idx, tok in enumerate(tokens_or_tags_set)}
    idx2tok = {idx:tok for idx, tok in enumerate(tokens_or_tags_set)}
    return tok2idx, idx2tok

# %% [markdown]
# After implementing the function *build_dict* you can make dictionaries for tokens and tags. Special tokens in our case will be:
#  - `<UNK>` token for out of vocabulary tokens;
#  - `<PAD>` token for padding sentence to the same length when we create batches of sentences.

# %%
special_tokens = ['<UNK>', '<PAD>']
special_tags = ['O']

# Create dictionaries 
token2idx, idx2token = build_dict(train_tokens + validation_tokens + test_tokens, special_tokens)
tag2idx, idx2tag = build_dict(train_tags, special_tags)

# %%
token2idx
# Out:
# {'<UNK>': 0,
#  'making': 1,
#  'Another': 2,
#  'Scents': 3,
#  'Varum': 4,
#  'rubbish': 5,
#  '2B': 6,
#  '#AtlDonut': 7,
#  '10%': 8,
#  'didi': 9,
#  'Charles': 10,
#  'erg': 11,
#  'cold': 12,
#  'dengan': 13,
#  '#Southie': 14,
#  "alive'...": 15,
#  'mums': 16,
#  'REALLY': 17,
#  'shooting…': 18,
#  'toetsen': 19,
#  'bruder': 20,
#  'fueling': 21,
#  'fizzy': 22,
#  'Coldplay': 23,
#  'pushes': 24,
#  'Throwers': 25,
#  'RT@vincewelch': 26,
#  'IDs': 27,
#  '(geloof': 28,
#  '$FXI': 29,
#  'COMMING': 30,
#  'KIPPUR': 31,
#  'hunting': 32,
#  'Louis': 33,
#  'Wazza': 34,
#  'go': 35,
#  '#Apple': 36,
#  'Passes': 37,
#  'Estate': 38,
#  'Crap': 39,
#  'Maroon': 40,
#  'Res': 41,
#  'kings': 42,
#  'Bagan': 43,
#  'COURSE': 44,
#  'debt': 45,
#  'hurling': 46,
#  "T'ES": 47,
#  'pic.twitter.com/5zpRGvwNKy': 48,
#  'comedy': 49,
#  'infestation': 50,
#  'knees': 51,
#  'Russia’s': 52,
#  'Meskipun': 53,
#  'Allah': 54,
#  'TPC-Audubon': 55,
#  "have'n": 56,
#  'unemployed': 57,
#  'MOTHER': 58,
#  'Nah': 59,
#  '#Dominion': 60,
#  '#Cobber': 61,
#  'Drive': 62,
#  'homage': 63,
#  'FORGET': 64,
#  'rooted': 65,
#  '3052507': 66,
#  'combine': 67,
#  'goooood': 68,
#  'supporter': 69,
#  'DAYS': 70,
#  'Spa': 71,
#  'magsspam': 72,
#  '#IOS9': 73,
#  'RevA': 74,
#  '#Tktmstr': 75,
#  'display': 76,
#  'soooo': 77,
#  'ptdr': 78,
#  'outs': 79,
#  'pound': 80,
#  'YAAASSS': 81,
#  'inoffice': 82,
#  'RECLAMATION': 83,
#  'yet(': 84,
#  '?"': 85,
#  'Candlelight': 86,
#  'mariaelena': 87,
#  'news.sky.com/story/1656777/is-registration-forms-identify-22000-jihadis': 88,
#  '#I95': 89,
#  '#iPhone': 90,
#  '225': 91,
#  'cloudy': 92,
#  'Every': 93,
#  'afraid': 94,
#  'personnel': 95,
#  'Ducati': 96,
#  'print': 97,
#  '?!?': 98,
#  'bomb': 99,
#  'Edition)By': 100,
#  'Unsung': 101,
#  '#Xbox': 102,
#  '#Colts': 103,
#  "We've": 104,
#  'bring': 105,
#  'Magcoconcert': 106,
#  'elsewhere': 107,
#  'passion': 108,
#  'Feature': 109,
#  'scholars': 110,
#  'Favorites': 111,
#  'causes': 112,
#  'S.S': 113,
#  'faced': 114,
#  'Effect': 115,
#  '25th': 116,
#  'sue': 117,
#  '#smiles': 118,
#  'picnic': 119,
#  'Daytime': 120,
#  'those': 121,
#  'Lincoln': 122,
#  'Save': 123,
#  '-___-op': 124,
#  'by': 125,
#  'Asa': 126,
#  'Papers': 127,
#  'Signal': 128,
#  'Tarik': 129,
#  'BWW': 130,
#  'SendGrid': 131,
#  'call/text': 132,
#  'Hardwood': 133,
#  'Bondi': 134,
#  'Math': 135,
#  'provider': 136,
#  'Imaginez': 137,
#  'Happenings': 138,
#  'Holtz': 139,
#  'JOVETIC': 140,
#  'Creek': 141,
#  'As': 142,
#  'Fever': 143,
#  'proper': 144,
#  'Wilson': 145,
#  '#PJNET': 146,
#  'Fiction': 147,
#  '#greaterlala': 148,
#  'caring': 149,
#  'waited': 150,
#  'Flood': 151,
#  'Bid': 152,
#  'danger': 153,
#  '%#$&amp;@%$&amp;%&amp;@$': 154,
#  'apply': 155,
#  'confetti*': 156,
#  'Champion': 157,
#  'Spectacular': 158,
#  'these': 159,
#  'copy': 160,
#  'Department': 161,
#  '#Cemaes': 162,
#  'Fitted': 163,
#  'windows': 164,
#  '#MStar': 165,
#  'Mama': 166,
#  'decreed': 167,
#  'dia': 168,
#  '#DALvsGB': 169,
#  'Sun': 170,
#  'criticism': 171,
#  'kicu': 172,
#  '#SELFISH': 173,
#  '8====': 174,
#  'Classes': 175,
#  'PJ': 176,
#  'black-blue': 177,
#  'Ngtxt': 178,
#  'steve': 179,
#  'TOTALLY': 180,
#  'Tattoos': 181,
#  'kanila': 182,
#  'Papel': 183,
#  'CRUSH': 184,
#  '129': 185,
#  '$204M': 186,
#  "d'avoir": 187,
#  'AKA': 188,
#  '20k': 189,
#  '2am': 190,
#  'I': 191,
#  'tuition': 192,
#  'M&amp;A': 193,
#  'sec': 194,
#  'Abroad': 195,
#  'professor': 196,
#  'i`ll': 197,
#  'England': 198,
#  '?:': 199,
#  'Calendar': 200,
#  'Dear': 201,
#  'xk': 202,
#  'FH': 203,
#  'birmingham': 204,
#  '#ZodiacFacts': 205,
#  'Cristobal': 206,
#  'LOOOK': 207,
#  '#ALDUB19thWeeksary': 208,
#  'Caught': 209,
#  'PA++': 210,
#  'relevant': 211,
#  'Malhotra': 212,
#  'box': 213,
#  'murderer': 214,
#  'opportunity': 215,
#  '#PushAwardsKathNiels': 216,
#  'seq': 217,
#  '#killthecheerleader': 218,
#  'CAA': 219,
#  'Dejavu': 220,
#  '(((': 221,
#  'dating': 222,
#  'GUSTA': 223,
#  '1s': 224,
#  '#Chattanooga': 225,
#  'severe': 226,
#  'Pranab': 227,
#  'Onward': 228,
#  '*inserts': 229,
#  'Tough': 230,
#  'BABALA': 231,
#  'commenters': 232,
#  'ya//': 233,
#  'Broncs': 234,
#  '#JCSU': 235,
#  'kalo': 236,
#  'Floyd': 237,
#  '330-1130': 238,
#  'acupuncture': 239,
#  'tanggung': 240,
#  '#SalesianVolleyball': 241,
#  '#forsale': 242,
#  'up*': 243,
#  'Sta': 244,
#  'Monthsary': 245,
#  't.v': 246,
#  'aam': 247,
#  'launch': 248,
#  'east': 249,
#  'crossed': 250,
#  'ATTENDAIS': 251,
#  'acara': 252,
#  '#959sunfm': 253,
#  'mdrrrrr': 254,
#  'MAIN': 255,
#  '03:51': 256,
#  '#EFC': 257,
#  'vision': 258,
#  'neo-nazis': 259,
#  'min': 260,
#  'wireless': 261,
#  'claim': 262,
#  'Django': 263,
#  'Joyous': 264,
#  'beschikbaar': 265,
#  '#DACA': 266,
#  'kpop': 267,
#  'BIRTHDY': 268,
#  'BAZAAR': 269,
#  'Illest': 270,
#  'proceed': 271,
#  'tried': 272,
#  'AstronomersWithoutBorders': 273,
#  'DOUCHEBAG': 274,
#  '1961': 275,
#  'genre': 276,
#  'VA': 277,
#  'dragged': 278,
#  'Standing': 279,
#  'passwords': 280,
#  '-the': 281,
#  'answer': 282,
#  'pilit': 283,
#  'UMASA': 284,
#  'next': 285,
#  'DONATE': 286,
#  'forth': 287,
#  'Roman': 288,
#  'blast(s': 289,
#  'Medium': 290,
#  'Ok': 291,
#  '#PremierLeague': 292,
#  'modernize': 293,
#  'Approaches': 294,
#  'wig)': 295,
#  'FOX': 296,
#  '102nd': 297,
#  'Luca': 298,
#  '#doinme': 299,
#  'challenges': 300,
#  'Database': 301,
#  'Scoot': 302,
#  'BETTER': 303,
#  '12/12)': 304,
#  'ahora': 305,
#  '#Detroit': 306,
#  "i'ma": 307,
#  '10th-12th': 308,
#  'Jigawa': 309,
#  'PTDR': 310,
#  'Labels': 311,
#  'Mahirap': 312,
#  'mandel': 313,
#  'lick': 314,
#  '01:46': 315,
#  'infinite': 316,
#  'automatically': 317,
#  '5:59': 318,
#  'Spieth': 319,
#  'eleanormarksprior': 320,
#  'iba': 321,
#  'Yanks': 322,
#  'spilled': 323,
#  'HOLIDAY': 324,
#  'antique': 325,
#  'Mesa': 326,
#  'Williams-Sonoma': 327,
#  'Fathers': 328,
#  'Maine': 329,
#  'Mei': 330,
#  'Germany': 331,
#  'LFL02': 332,
#  'dalo': 333,
#  'Bands': 334,
#  'Delivery': 335,
#  'ranged': 336,
#  'Tips': 337,
#  'hotter': 338,
#  'RCTI': 339,
#  'corridor': 340,
#  'Though': 341,
#  'hefty': 342,
#  'clowns': 343,
#  'Butterfly': 344,
#  'Ben': 345,
#  '12.00': 346,
#  'Apink': 347,
#  '150.00': 348,
#  'ORDERS': 349,
#  'marched': 350,
#  'him*': 351,
#  'rapping': 352,
#  '*Danielle': 353,
#  'stalker': 354,
#  'Jennifer': 355,
#  'wsup': 356,
#  'Ohhh': 357,
#  '#detroit': 358,
#  "':::": 359,
#  'gouging': 360,
#  'Last-minute': 361,
#  'y': 362,
#  'DID': 363,
#  'Narnia': 364,
#  'hair': 365,
#  '6': 366,
#  'surgery': 367,
#  'connecting': 368,
#  '#BirthdayGift': 369,
#  'me..Parlae': 370,
#  'HTML': 371,
#  'SOCHI': 372,
#  'sooooo': 373,
#  'Na': 374,
#  'NRA': 375,
#  'Football': 376,
#  'Wage': 377,
#  'Twitpic': 378,
#  '#Parenting': 379,
#  '#Oban-#Colonsay': 380,
#  'tackles': 381,
#  '200,000': 382,
#  '#bailondsmaricopacounty': 383,
#  'Regrowth': 384,
#  'Mackail-Smith': 385,
#  'live': 386,
#  'Cases': 387,
#  '27th': 388,
#  'Nex-Tech': 389,
#  'TAENA': 390,
#  'Chad': 391,
#  'mad': 392,
#  '34637': 393,
#  'maka': 394,
#  '8-10pm': 395,
#  '#MichiganCityBuoy': 396,
#  'Lowkey': 397,
#  '300,000': 398,
#  '#WBZ': 399,
#  'Red': 400,
#  '#urge': 401,
#  'NAME': 402,
#  'couldnt': 403,
#  'resigning': 404,
#  'Second-year': 405,
#  'Afterparty': 406,
#  'shirtless': 407,
#  'yes': 408,
#  'thiiis': 409,
#  'PICTURES': 410,
#  'spending': 411,
#  'Announces': 412,
#  'pre-order': 413,
#  'Libya': 414,
#  'wind': 415,
#  'Coach': 416,
#  'hehe': 417,
#  '9:00': 418,
#  'Taorminaa': 419,
#  '#FOURVinyl': 420,
#  'parade': 421,
#  '#DearPopeFrancis': 422,
#  '#kopen': 423,
#  'Necklace': 424,
#  'horrific': 425,
#  'Regarding': 426,
#  'bench': 427,
#  'au': 428,
#  'Break': 429,
#  '03:24': 430,
#  'hackathon': 431,
#  'realllllll': 432,
#  '10mins': 433,
#  'alam': 434,
#  'stone': 435,
#  'staat': 436,
#  'Keller': 437,
#  'ami': 438,
#  'MNF': 439,
#  '#SensoryPlay': 440,
#  'dire': 441,
#  'mai': 442,
#  '#ACCESSTOHES': 443,
#  'rare': 444,
#  '#ddos': 445,
#  'FIFA': 446,
#  '8.31': 447,
#  '#major': 448,
#  '#Heinz': 449,
#  'ses': 450,
#  'Giles': 451,
#  'hoax': 452,
#  '#london': 453,
#  'Commander': 454,
#  '#lightitup': 455,
#  'Asprin': 456,
#  '09:53': 457,
#  '11:50': 458,
#  'BLAST': 459,
#  'shithead': 460,
#  'affects': 461,
#  "WE'LL": 462,
#  'Oma': 463,
#  'Telly': 464,
#  'Rainy': 465,
#  'Rarity': 466,
#  'Homies': 467,
#  'schedules': 468,
#  'Voices': 469,
#  '#vlog': 470,
#  'Zionist': 471,
#  'Gray': 472,
#  "travels!I'll": 473,
#  'Unknown': 474,
#  'buttery': 475,
#  '#cybercrime': 476,
#  '*happy': 477,
#  'shor': 478,
#  'presented': 479,
#  'Spf': 480,
#  'Whoa': 481,
#  'SEO': 482,
#  '#Speech': 483,
#  'justin': 484,
#  'hardware': 485,
#  'Busch': 486,
#  '#Huawei': 487,
#  'Loket': 488,
#  'off*': 489,
#  'Group/Eagle': 490,
#  'Powered': 491,
#  '#realestate': 492,
#  'eats': 493,
#  'Cuts': 494,
#  'Downtown': 495,
#  'miren': 496,
#  'Busy': 497,
#  'hun': 498,
#  'unbearable': 499,
#  'principles': 500,
#  'System': 501,
#  '1st-rd': 502,
#  'extremely': 503,
#  'cigarette': 504,
#  '#BREAKING': 505,
#  'Movement': 506,
#  'Shettt': 507,
#  'HOPEFULLY': 508,
#  'essay': 509,
#  'bars': 510,
#  'tersayangg': 511,
#  'Prize': 512,
#  'Also': 513,
#  'Shane': 514,
#  'Doris': 515,
#  '86': 516,
#  'dishes': 517,
#  'China': 518,
#  'Why': 519,
#  '#car': 520,
#  'play': 521,
#  'ie': 522,
#  'biar': 523,
#  '#ElectionsMatter': 524,
#  '02:54': 525,
#  'latest': 526,
#  'committee': 527,
#  '#Royals': 528,
#  'strongest': 529,
#  'escaped': 530,
#  'tomar': 531,
#  'athletic': 532,
#  'El-Rufai': 533,
#  'Unremarkable': 534,
#  'AEDT': 535,
#  'overlooking': 536,
#  '6:16': 537,
#  'LMao': 538,
#  'paris': 539,
#  'ink': 540,
#  'naba': 541,
#  'Followed': 542,
#  '4G': 543,
#  '#Cochrane': 544,
#  'Jurassic': 545,
#  'Clouds': 546,
#  'earning': 547,
#  'easy': 548,
#  '#Android': 549,
#  '23': 550,
#  'header': 551,
#  'oldskool': 552,
#  'scary': 553,
#  'Neil': 554,
#  'lyk': 555,
#  'haircut': 556,
#  'Shake': 557,
#  '#followback': 558,
#  'back-Big': 559,
#  'iBGP': 560,
#  '#mlb': 561,
#  '*evil': 562,
#  '#rejoice': 563,
#  '#theguardian': 564,
#  "breach',": 565,
#  'MONTH': 566,
#  '21-7': 567,
#  'Search': 568,
#  'load': 569,
#  '116': 570,
#  '#election': 571,
#  'robot': 572,
#  'Science': 573,
#  'GUYSSS': 574,
#  '#itaintmines': 575,
#  'prepaid': 576,
#  'YESSSSSS': 577,
#  'restaurants': 578,
#  'Polar': 579,
#  'quarter': 580,
#  'Bag': 581,
#  '#NXTTakeOver': 582,
#  'Selena': 583,
#  'ayaw': 584,
#  '81': 585,
#  'OaklandArtsSchool': 586,
#  'fled': 587,
#  'Woo': 588,
#  'Americans': 589,
#  'costs': 590,
#  '#uspro': 591,
#  'spell': 592,
#  'salle': 593,
#  'behavior': 594,
#  '#TECHINFO': 595,
#  'Scottish': 596,
#  'Bie': 597,
#  'Onga': 598,
#  'Willow': 599,
#  'Observe': 600,
#  'TeamiPhone': 601,
#  ".'": 602,
#  'ikan': 603,
#  'Sihler': 604,
#  'cafe': 605,
#  'teehee': 606,
#  'Uth': 607,
#  'MODEL': 608,
#  'Jannah': 609,
#  'qualifying': 610,
#  'taLked': 611,
#  '704-428-9009': 612,
#  'professional': 613,
#  '!!!!!!!!': 614,
#  'sd': 615,
#  'authorities': 616,
#  'SUMMER': 617,
#  'Hack': 618,
#  'Delaware': 619,
#  'aphrodisiacs': 620,
#  'Sources': 621,
#  'volunteering': 622,
#  'Bulan': 623,
#  'Luckily': 624,
#  '13/10': 625,
#  'Conversations': 626,
#  'Recruitment': 627,
#  '#BoardwalkEmpire': 628,
#  '#Sheffield': 629,
#  'Bears': 630,
#  'Barrow': 631,
#  '#17': 632,
#  'repaired': 633,
#  'Fabulous': 634,
#  'Send': 635,
#  '??"': 636,
#  'Hulk': 637,
#  'permitted': 638,
#  'Titan': 639,
#  'Offense': 640,
#  'kailan': 641,
#  'quelqun': 642,
#  'pic.twitter.com/rgd2ZKv5LC”look': 643,
#  'Assembly': 644,
#  '#damnteenquotes': 645,
#  'loaded': 646,
#  'COMING': 647,
#  'TAYLOR': 648,
#  'frere': 649,
#  'Cape': 650,
#  'Sc': 651,
#  'PHILIPPINES': 652,
#  'Chief': 653,
#  'cussin': 654,
#  'Officer-involved': 655,
#  'grass': 656,
#  'Diaper': 657,
#  'humeur': 658,
#  'Egeo': 659,
#  'Oven': 660,
#  '458': 661,
#  'GPD': 662,
#  'Humidity': 663,
#  'qui': 664,
#  'amendments': 665,
#  '#draislive': 666,
#  'cover': 667,
#  'Blog': 668,
#  'user': 669,
#  'demolished': 670,
#  'sad-just': 671,
#  'W/Joe': 672,
#  'imdb': 673,
#  'Southern': 674,
#  '#blocked': 675,
#  'Nieuws': 676,
#  '#hack': 677,
#  'Image': 678,
#  'scream': 679,
#  'COMMENT': 680,
#  'response': 681,
#  'Aka': 682,
#  'ily': 683,
#  'TAE': 684,
#  'MGBSFL': 685,
#  'An': 686,
#  'drive-by': 687,
#  'astonishing': 688,
#  'folks': 689,
#  'SQL': 690,
#  'conduct': 691,
#  '#Sustainability': 692,
#  'eyeliner': 693,
#  'london': 694,
#  '#Arkansas': 695,
#  'Downey': 696,
#  'citizenry': 697,
#  '#HIPAA': 698,
#  '#StingVsTripleH': 699,
#  '#hunger': 700,
#  'dawg': 701,
#  '#resume': 702,
#  'repeat': 703,
#  'clock': 704,
#  '-RJJ”': 705,
#  'Johannesburg': 706,
#  'dance': 707,
#  'OOC': 708,
#  '#SQLi': 709,
#  'Tonight-Local': 710,
#  'sparri': 711,
#  'choices': 712,
#  '3lelaki': 713,
#  'Nichkhun': 714,
#  'Intellectual': 715,
#  '`MAMA`': 716,
#  'WEIRD': 717,
#  'dele': 718,
#  'Uve': 719,
#  'Lls': 720,
#  'Switzerland': 721,
#  '9.99': 722,
#  're': 723,
#  'listings': 724,
#  '#TheForceAwakens': 725,
#  'watershed': 726,
#  'complex': 727,
#  'Hamm': 728,
#  'and': 729,
#  '#Retweet': 730,
#  'MovieSoonFor': 731,
#  'Draft': 732,
#  'furniture': 733,
#  'SKE48': 734,
#  'Cachupas': 735,
#  'nombre': 736,
#  'GA': 737,
#  'Bawana': 738,
#  '02:36': 739,
#  'JAN': 740,
#  'Furukawa': 741,
#  'bias': 742,
#  'meant': 743,
#  'Interviews': 744,
#  'declassification': 745,
#  'sundays': 746,
#  'NE': 747,
#  'Leche': 748,
#  'seeing': 749,
#  'ris': 750,
#  'Lessons': 751,
#  '#6': 752,
#  'entails': 753,
#  'banned': 754,
#  'Yahoo': 755,
#  'custom': 756,
#  'Dani': 757,
#  'moonlight': 758,
#  'SKY': 759,
#  'chelsea': 760,
#  'potatoes': 761,
#  '#PassionParties': 762,
#  'Kiran': 763,
#  'wash': 764,
#  'ftw': 765,
#  'manija': 766,
#  "O'clock.": 767,
#  'ngiler': 768,
#  'Earle': 769,
#  '#useless': 770,
#  'Climbing': 771,
#  'ECPC': 772,
#  'aming': 773,
#  'VW': 774,
#  'popularity': 775,
#  'kaibigan': 776,
#  'Rab': 777,
#  'Cocaine': 778,
#  'kc': 779,
#  'Score': 780,
#  'Sus': 781,
#  '#HnF': 782,
#  'Samui': 783,
#  'Brigade': 784,
#  ',?': 785,
#  'Voxel8': 786,
#  'Teenage': 787,
#  'Gilberto': 788,
#  'anxiety': 789,
#  'stared': 790,
#  'drive': 791,
#  '#Cabinet': 792,
#  'Pokemon': 793,
#  'frees': 794,
#  'sana': 795,
#  'ibe': 796,
#  'Barometric': 797,
#  'Clear': 798,
#  'Mukherjee': 799,
#  '13th': 800,
#  'ECS': 801,
#  'AT&amp;T': 802,
#  'Mas': 803,
#  'Kshs': 804,
#  'maintenant': 805,
#  'BROTHER': 806,
#  'FEBRUARY': 807,
#  'Shoutout': 808,
#  'recruits': 809,
#  'woot': 810,
#  'moves': 811,
#  '3/5': 812,
#  'prank': 813,
#  'Logging': 814,
#  '#STLCards': 815,
#  'LiLo': 816,
#  'Ashutosh': 817,
#  'Pre': 818,
#  'covered': 819,
#  '#DataBreachhttp': 820,
#  'beans': 821,
#  'Buford': 822,
#  'helmet': 823,
#  'Paalam': 824,
#  'three': 825,
#  'wertheim': 826,
#  'Little': 827,
#  '#Spurs': 828,
#  'quando': 829,
#  '#premierleague': 830,
#  'label': 831,
#  'DAY6': 832,
#  'syang': 833,
#  'and/fatt': 834,
#  'phil': 835,
#  'pendaftaran': 836,
#  '#TeenWolf': 837,
#  'cobalah': 838,
#  'scarey': 839,
#  'Tenshi': 840,
#  'beberkan': 841,
#  'Inception': 842,
#  'brazos': 843,
#  'EDITION': 844,
#  'Correct': 845,
#  'clutch': 846,
#  'temp': 847,
#  'punchline': 848,
#  'latimes': 849,
#  'Coinbase': 850,
#  'Favre': 851,
#  'Filipino': 852,
#  'blmd': 853,
#  'PangakoSayo': 854,
#  'possibly': 855,
#  'Rain': 856,
#  'havoc': 857,
#  'PDT': 858,
#  'avoided': 859,
#  'sobrang': 860,
#  'CONSOLIDA': 861,
#  '25%': 862,
#  'Zennie62': 863,
#  'Dirk': 864,
#  'Savoirfaire': 865,
#  'Renault': 866,
#  'sejak': 867,
#  'sheep': 868,
#  'lingerie': 869,
#  'machines': 870,
#  'Progress': 871,
#  'Boards': 872,
#  'Tip': 873,
#  '#Beach': 874,
#  'Came': 875,
#  'ASISTEN': 876,
#  '#softballready': 877,
#  'Catherine': 878,
#  'entrain': 879,
#  '#911': 880,
#  'longg': 881,
#  'yapping': 882,
#  '#severewx': 883,
#  'Funny': 884,
#  '#Mumbai': 885,
#  'destiny': 886,
#  'IE': 887,
#  'rad': 888,
#  'complain': 889,
#  'Rican': 890,
#  'Hopeful': 891,
#  'sorbet': 892,
#  'yours': 893,
#  'Teachers': 894,
#  'enters': 895,
#  'lambrini': 896,
#  'flipping': 897,
#  'stunts': 898,
#  'bikinis': 899,
#  'solutions': 900,
#  'migranti': 901,
#  'Whiteside': 902,
#  'kang': 903,
#  'masamang': 904,
#  'Hydrating': 905,
#  'papasok': 906,
#  'Story': 907,
#  '1dlovesoned': 908,
#  'Atwater': 909,
#  'Laughlin': 910,
#  'Pavonia': 911,
#  'Exchange': 912,
#  'Juicy': 913,
#  'akomg': 914,
#  'tally': 915,
#  'LGBT': 916,
#  'two': 917,
#  'DING': 918,
#  'are': 919,
#  'Feet': 920,
#  'Theeeeeeeeeee': 921,
#  'Donating': 922,
#  'chewables': 923,
#  'MOTD': 924,
#  'US/Eastern)': 925,
#  "Didn't": 926,
#  'grater': 927,
#  '20:10': 928,
#  '+3': 929,
#  'Fasting': 930,
#  'turn': 931,
#  'convention': 932,
#  'PIC': 933,
#  'Megan': 934,
#  'INVITATION': 935,
#  'lose': 936,
#  '#TGIBF': 937,
#  'Camino': 938,
#  'K-POP': 939,
#  'Bordeaux': 940,
#  'Mancini': 941,
#  'alejo': 942,
#  '03:20': 943,
#  '#tweetbatt': 944,
#  'probs': 945,
#  'Roberto': 946,
#  '#Touchnote': 947,
#  'Massive': 948,
#  'PIT': 949,
#  'pill': 950,
#  'Dun': 951,
#  'reset': 952,
#  'Exposure': 953,
#  'Pulling': 954,
#  '#readit': 955,
#  "Hahaha'": 956,
#  'block': 957,
#  'los': 958,
#  'rode': 959,
#  '501': 960,
#  'registered': 961,
#  'Unarmed': 962,
#  'wtf': 963,
#  'Montgomery': 964,
#  'nutshell': 965,
#  'iffy': 966,
#  'songz': 967,
#  'sunday': 968,
#  'Kainis': 969,
#  'john@thelittleaussiebakery': 970,
#  'needing': 971,
#  'perfom': 972,
#  'TEAM': 973,
#  '#WonderGirls': 974,
#  'Dame': 975,
#  '#growinguptoofast': 976,
#  'eyes*': 977,
#  '#giveaways': 978,
#  'Omaha': 979,
#  'BlackBerry': 980,
#  '#InOMN10': 981,
#  'Parti': 982,
#  'Strongest': 983,
#  'Dec-28-2014': 984,
#  'est': 985,
#  'smiley': 986,
#  '#COYR': 987,
#  'chasin': 988,
#  '#Salamanca': 989,
#  'NIGHT': 990,
#  'Tour': 991,
#  'Aaaaah': 992,
#  'tryin': 993,
#  'bash': 994,
#  'ewan': 995,
#  'Hold': 996,
#  '#Rachel': 997,
#  'Andrew': 998,
#  'MAIL': 999,
#  ...}

# %%
idx2token
# Out:
# {0: '<UNK>',
#  1: 'making',
#  2: 'Another',
#  3: 'Scents',
#  4: 'Varum',
#  5: 'rubbish',
#  6: '2B',
#  7: '#AtlDonut',
#  8: '10%',
#  9: 'didi',
#  10: 'Charles',
#  11: 'erg',
#  12: 'cold',
#  13: 'dengan',
#  14: '#Southie',
#  15: "alive'...",
#  16: 'mums',
#  17: 'REALLY',
#  18: 'shooting…',
#  19: 'toetsen',
#  20: 'bruder',
#  21: 'fueling',
#  22: 'fizzy',
#  23: 'Coldplay',
#  24: 'pushes',
#  25: 'Throwers',
#  26: 'RT@vincewelch',
#  27: 'IDs',
#  28: '(geloof',
#  29: '$FXI',
#  30: 'COMMING',
#  31: 'KIPPUR',
#  32: 'hunting',
#  33: 'Louis',
#  34: 'Wazza',
#  35: 'go',
#  36: '#Apple',
#  37: 'Passes',
#  38: 'Estate',
#  39: 'Crap',
#  40: 'Maroon',
#  41: 'Res',
#  42: 'kings',
#  43: 'Bagan',
#  44: 'COURSE',
#  45: 'debt',
#  46: 'hurling',
#  47: "T'ES",
#  48: 'pic.twitter.com/5zpRGvwNKy',
#  49: 'comedy',
#  50: 'infestation',
#  51: 'knees',
#  52: 'Russia’s',
#  53: 'Meskipun',
#  54: 'Allah',
#  55: 'TPC-Audubon',
#  56: "have'n",
#  57: 'unemployed',
#  58: 'MOTHER',
#  59: 'Nah',
#  60: '#Dominion',
#  61: '#Cobber',
#  62: 'Drive',
#  63: 'homage',
#  64: 'FORGET',
#  65: 'rooted',
#  66: '3052507',
#  67: 'combine',
#  68: 'goooood',
#  69: 'supporter',
#  70: 'DAYS',
#  71: 'Spa',
#  72: 'magsspam',
#  73: '#IOS9',
#  74: 'RevA',
#  75: '#Tktmstr',
#  76: 'display',
#  77: 'soooo',
#  78: 'ptdr',
#  79: 'outs',
#  80: 'pound',
#  81: 'YAAASSS',
#  82: 'inoffice',
#  83: 'RECLAMATION',
#  84: 'yet(',
#  85: '?"',
#  86: 'Candlelight',
#  87: 'mariaelena',
#  88: 'news.sky.com/story/1656777/is-registration-forms-identify-22000-jihadis',
#  89: '#I95',
#  90: '#iPhone',
#  91: '225',
#  92: 'cloudy',
#  93: 'Every',
#  94: 'afraid',
#  95: 'personnel',
#  96: 'Ducati',
#  97: 'print',
#  98: '?!?',
#  99: 'bomb',
#  100: 'Edition)By',
#  101: 'Unsung',
#  102: '#Xbox',
#  103: '#Colts',
#  104: "We've",
#  105: 'bring',
#  106: 'Magcoconcert',
#  107: 'elsewhere',
#  108: 'passion',
#  109: 'Feature',
#  110: 'scholars',
#  111: 'Favorites',
#  112: 'causes',
#  113: 'S.S',
#  114: 'faced',
#  115: 'Effect',
#  116: '25th',
#  117: 'sue',
#  118: '#smiles',
#  119: 'picnic',
#  120: 'Daytime',
#  121: 'those',
#  122: 'Lincoln',
#  123: 'Save',
#  124: '-___-op',
#  125: 'by',
#  126: 'Asa',
#  127: 'Papers',
#  128: 'Signal',
#  129: 'Tarik',
#  130: 'BWW',
#  131: 'SendGrid',
#  132: 'call/text',
#  133: 'Hardwood',
#  134: 'Bondi',
#  135: 'Math',
#  136: 'provider',
#  137: 'Imaginez',
#  138: 'Happenings',
#  139: 'Holtz',
#  140: 'JOVETIC',
#  141: 'Creek',
#  142: 'As',
#  143: 'Fever',
#  144: 'proper',
#  145: 'Wilson',
#  146: '#PJNET',
#  147: 'Fiction',
#  148: '#greaterlala',
#  149: 'caring',
#  150: 'waited',
#  151: 'Flood',
#  152: 'Bid',
#  153: 'danger',
#  154: '%#$&amp;@%$&amp;%&amp;@$',
#  155: 'apply',
#  156: 'confetti*',
#  157: 'Champion',
#  158: 'Spectacular',
#  159: 'these',
#  160: 'copy',
#  161: 'Department',
#  162: '#Cemaes',
#  163: 'Fitted',
#  164: 'windows',
#  165: '#MStar',
#  166: 'Mama',
#  167: 'decreed',
#  168: 'dia',
#  169: '#DALvsGB',
#  170: 'Sun',
#  171: 'criticism',
#  172: 'kicu',
#  173: '#SELFISH',
#  174: '8====',
#  175: 'Classes',
#  176: 'PJ',
#  177: 'black-blue',
#  178: 'Ngtxt',
#  179: 'steve',
#  180: 'TOTALLY',
#  181: 'Tattoos',
#  182: 'kanila',
#  183: 'Papel',
#  184: 'CRUSH',
#  185: '129',
#  186: '$204M',
#  187: "d'avoir",
#  188: 'AKA',
#  189: '20k',
#  190: '2am',
#  191: 'I',
#  192: 'tuition',
#  193: 'M&amp;A',
#  194: 'sec',
#  195: 'Abroad',
#  196: 'professor',
#  197: 'i`ll',
#  198: 'England',
#  199: '?:',
#  200: 'Calendar',
#  201: 'Dear',
#  202: 'xk',
#  203: 'FH',
#  204: 'birmingham',
#  205: '#ZodiacFacts',
#  206: 'Cristobal',
#  207: 'LOOOK',
#  208: '#ALDUB19thWeeksary',
#  209: 'Caught',
#  210: 'PA++',
#  211: 'relevant',
#  212: 'Malhotra',
#  213: 'box',
#  214: 'murderer',
#  215: 'opportunity',
#  216: '#PushAwardsKathNiels',
#  217: 'seq',
#  218: '#killthecheerleader',
#  219: 'CAA',
#  220: 'Dejavu',
#  221: '(((',
#  222: 'dating',
#  223: 'GUSTA',
#  224: '1s',
#  225: '#Chattanooga',
#  226: 'severe',
#  227: 'Pranab',
#  228: 'Onward',
#  229: '*inserts',
#  230: 'Tough',
#  231: 'BABALA',
#  232: 'commenters',
#  233: 'ya//',
#  234: 'Broncs',
#  235: '#JCSU',
#  236: 'kalo',
#  237: 'Floyd',
#  238: '330-1130',
#  239: 'acupuncture',
#  240: 'tanggung',
#  241: '#SalesianVolleyball',
#  242: '#forsale',
#  243: 'up*',
#  244: 'Sta',
#  245: 'Monthsary',
#  246: 't.v',
#  247: 'aam',
#  248: 'launch',
#  249: 'east',
#  250: 'crossed',
#  251: 'ATTENDAIS',
#  252: 'acara',
#  253: '#959sunfm',
#  254: 'mdrrrrr',
#  255: 'MAIN',
#  256: '03:51',
#  257: '#EFC',
#  258: 'vision',
#  259: 'neo-nazis',
#  260: 'min',
#  261: 'wireless',
#  262: 'claim',
#  263: 'Django',
#  264: 'Joyous',
#  265: 'beschikbaar',
#  266: '#DACA',
#  267: 'kpop',
#  268: 'BIRTHDY',
#  269: 'BAZAAR',
#  270: 'Illest',
#  271: 'proceed',
#  272: 'tried',
#  273: 'AstronomersWithoutBorders',
#  274: 'DOUCHEBAG',
#  275: '1961',
#  276: 'genre',
#  277: 'VA',
#  278: 'dragged',
#  279: 'Standing',
#  280: 'passwords',
#  281: '-the',
#  282: 'answer',
#  283: 'pilit',
#  284: 'UMASA',
#  285: 'next',
#  286: 'DONATE',
#  287: 'forth',
#  288: 'Roman',
#  289: 'blast(s',
#  290: 'Medium',
#  291: 'Ok',
#  292: '#PremierLeague',
#  293: 'modernize',
#  294: 'Approaches',
#  295: 'wig)',
#  296: 'FOX',
#  297: '102nd',
#  298: 'Luca',
#  299: '#doinme',
#  300: 'challenges',
#  301: 'Database',
#  302: 'Scoot',
#  303: 'BETTER',
#  304: '12/12)',
#  305: 'ahora',
#  306: '#Detroit',
#  307: "i'ma",
#  308: '10th-12th',
#  309: 'Jigawa',
#  310: 'PTDR',
#  311: 'Labels',
#  312: 'Mahirap',
#  313: 'mandel',
#  314: 'lick',
#  315: '01:46',
#  316: 'infinite',
#  317: 'automatically',
#  318: '5:59',
#  319: 'Spieth',
#  320: 'eleanormarksprior',
#  321: 'iba',
#  322: 'Yanks',
#  323: 'spilled',
#  324: 'HOLIDAY',
#  325: 'antique',
#  326: 'Mesa',
#  327: 'Williams-Sonoma',
#  328: 'Fathers',
#  329: 'Maine',
#  330: 'Mei',
#  331: 'Germany',
#  332: 'LFL02',
#  333: 'dalo',
#  334: 'Bands',
#  335: 'Delivery',
#  336: 'ranged',
#  337: 'Tips',
#  338: 'hotter',
#  339: 'RCTI',
#  340: 'corridor',
#  341: 'Though',
#  342: 'hefty',
#  343: 'clowns',
#  344: 'Butterfly',
#  345: 'Ben',
#  346: '12.00',
#  347: 'Apink',
#  348: '150.00',
#  349: 'ORDERS',
#  350: 'marched',
#  351: 'him*',
#  352: 'rapping',
#  353: '*Danielle',
#  354: 'stalker',
#  355: 'Jennifer',
#  356: 'wsup',
#  357: 'Ohhh',
#  358: '#detroit',
#  359: "':::",
#  360: 'gouging',
#  361: 'Last-minute',
#  362: 'y',
#  363: 'DID',
#  364: 'Narnia',
#  365: 'hair',
#  366: '6',
#  367: 'surgery',
#  368: 'connecting',
#  369: '#BirthdayGift',
#  370: 'me..Parlae',
#  371: 'HTML',
#  372: 'SOCHI',
#  373: 'sooooo',
#  374: 'Na',
#  375: 'NRA',
#  376: 'Football',
#  377: 'Wage',
#  378: 'Twitpic',
#  379: '#Parenting',
#  380: '#Oban-#Colonsay',
#  381: 'tackles',
#  382: '200,000',
#  383: '#bailondsmaricopacounty',
#  384: 'Regrowth',
#  385: 'Mackail-Smith',
#  386: 'live',
#  387: 'Cases',
#  388: '27th',
#  389: 'Nex-Tech',
#  390: 'TAENA',
#  391: 'Chad',
#  392: 'mad',
#  393: '34637',
#  394: 'maka',
#  395: '8-10pm',
#  396: '#MichiganCityBuoy',
#  397: 'Lowkey',
#  398: '300,000',
#  399: '#WBZ',
#  400: 'Red',
#  401: '#urge',
#  402: 'NAME',
#  403: 'couldnt',
#  404: 'resigning',
#  405: 'Second-year',
#  406: 'Afterparty',
#  407: 'shirtless',
#  408: 'yes',
#  409: 'thiiis',
#  410: 'PICTURES',
#  411: 'spending',
#  412: 'Announces',
#  413: 'pre-order',
#  414: 'Libya',
#  415: 'wind',
#  416: 'Coach',
#  417: 'hehe',
#  418: '9:00',
#  419: 'Taorminaa',
#  420: '#FOURVinyl',
#  421: 'parade',
#  422: '#DearPopeFrancis',
#  423: '#kopen',
#  424: 'Necklace',
#  425: 'horrific',
#  426: 'Regarding',
#  427: 'bench',
#  428: 'au',
#  429: 'Break',
#  430: '03:24',
#  431: 'hackathon',
#  432: 'realllllll',
#  433: '10mins',
#  434: 'alam',
#  435: 'stone',
#  436: 'staat',
#  437: 'Keller',
#  438: 'ami',
#  439: 'MNF',
#  440: '#SensoryPlay',
#  441: 'dire',
#  442: 'mai',
#  443: '#ACCESSTOHES',
#  444: 'rare',
#  445: '#ddos',
#  446: 'FIFA',
#  447: '8.31',
#  448: '#major',
#  449: '#Heinz',
#  450: 'ses',
#  451: 'Giles',
#  452: 'hoax',
#  453: '#london',
#  454: 'Commander',
#  455: '#lightitup',
#  456: 'Asprin',
#  457: '09:53',
#  458: '11:50',
#  459: 'BLAST',
#  460: 'shithead',
#  461: 'affects',
#  462: "WE'LL",
#  463: 'Oma',
#  464: 'Telly',
#  465: 'Rainy',
#  466: 'Rarity',
#  467: 'Homies',
#  468: 'schedules',
#  469: 'Voices',
#  470: '#vlog',
#  471: 'Zionist',
#  472: 'Gray',
#  473: "travels!I'll",
#  474: 'Unknown',
#  475: 'buttery',
#  476: '#cybercrime',
#  477: '*happy',
#  478: 'shor',
#  479: 'presented',
#  480: 'Spf',
#  481: 'Whoa',
#  482: 'SEO',
#  483: '#Speech',
#  484: 'justin',
#  485: 'hardware',
#  486: 'Busch',
#  487: '#Huawei',
#  488: 'Loket',
#  489: 'off*',
#  490: 'Group/Eagle',
#  491: 'Powered',
#  492: '#realestate',
#  493: 'eats',
#  494: 'Cuts',
#  495: 'Downtown',
#  496: 'miren',
#  497: 'Busy',
#  498: 'hun',
#  499: 'unbearable',
#  500: 'principles',
#  501: 'System',
#  502: '1st-rd',
#  503: 'extremely',
#  504: 'cigarette',
#  505: '#BREAKING',
#  506: 'Movement',
#  507: 'Shettt',
#  508: 'HOPEFULLY',
#  509: 'essay',
#  510: 'bars',
#  511: 'tersayangg',
#  512: 'Prize',
#  513: 'Also',
#  514: 'Shane',
#  515: 'Doris',
#  516: '86',
#  517: 'dishes',
#  518: 'China',
#  519: 'Why',
#  520: '#car',
#  521: 'play',
#  522: 'ie',
#  523: 'biar',
#  524: '#ElectionsMatter',
#  525: '02:54',
#  526: 'latest',
#  527: 'committee',
#  528: '#Royals',
#  529: 'strongest',
#  530: 'escaped',
#  531: 'tomar',
#  532: 'athletic',
#  533: 'El-Rufai',
#  534: 'Unremarkable',
#  535: 'AEDT',
#  536: 'overlooking',
#  537: '6:16',
#  538: 'LMao',
#  539: 'paris',
#  540: 'ink',
#  541: 'naba',
#  542: 'Followed',
#  543: '4G',
#  544: '#Cochrane',
#  545: 'Jurassic',
#  546: 'Clouds',
#  547: 'earning',
#  548: 'easy',
#  549: '#Android',
#  550: '23',
#  551: 'header',
#  552: 'oldskool',
#  553: 'scary',
#  554: 'Neil',
#  555: 'lyk',
#  556: 'haircut',
#  557: 'Shake',
#  558: '#followback',
#  559: 'back-Big',
#  560: 'iBGP',
#  561: '#mlb',
#  562: '*evil',
#  563: '#rejoice',
#  564: '#theguardian',
#  565: "breach',",
#  566: 'MONTH',
#  567: '21-7',
#  568: 'Search',
#  569: 'load',
#  570: '116',
#  571: '#election',
#  572: 'robot',
#  573: 'Science',
#  574: 'GUYSSS',
#  575: '#itaintmines',
#  576: 'prepaid',
#  577: 'YESSSSSS',
#  578: 'restaurants',
#  579: 'Polar',
#  580: 'quarter',
#  581: 'Bag',
#  582: '#NXTTakeOver',
#  583: 'Selena',
#  584: 'ayaw',
#  585: '81',
#  586: 'OaklandArtsSchool',
#  587: 'fled',
#  588: 'Woo',
#  589: 'Americans',
#  590: 'costs',
#  591: '#uspro',
#  592: 'spell',
#  593: 'salle',
#  594: 'behavior',
#  595: '#TECHINFO',
#  596: 'Scottish',
#  597: 'Bie',
#  598: 'Onga',
#  599: 'Willow',
#  600: 'Observe',
#  601: 'TeamiPhone',
#  602: ".'",
#  603: 'ikan',
#  604: 'Sihler',
#  605: 'cafe',
#  606: 'teehee',
#  607: 'Uth',
#  608: 'MODEL',
#  609: 'Jannah',
#  610: 'qualifying',
#  611: 'taLked',
#  612: '704-428-9009',
#  613: 'professional',
#  614: '!!!!!!!!',
#  615: 'sd',
#  616: 'authorities',
#  617: 'SUMMER',
#  618: 'Hack',
#  619: 'Delaware',
#  620: 'aphrodisiacs',
#  621: 'Sources',
#  622: 'volunteering',
#  623: 'Bulan',
#  624: 'Luckily',
#  625: '13/10',
#  626: 'Conversations',
#  627: 'Recruitment',
#  628: '#BoardwalkEmpire',
#  629: '#Sheffield',
#  630: 'Bears',
#  631: 'Barrow',
#  632: '#17',
#  633: 'repaired',
#  634: 'Fabulous',
#  635: 'Send',
#  636: '??"',
#  637: 'Hulk',
#  638: 'permitted',
#  639: 'Titan',
#  640: 'Offense',
#  641: 'kailan',
#  642: 'quelqun',
#  643: 'pic.twitter.com/rgd2ZKv5LC”look',
#  644: 'Assembly',
#  645: '#damnteenquotes',
#  646: 'loaded',
#  647: 'COMING',
#  648: 'TAYLOR',
#  649: 'frere',
#  650: 'Cape',
#  651: 'Sc',
#  652: 'PHILIPPINES',
#  653: 'Chief',
#  654: 'cussin',
#  655: 'Officer-involved',
#  656: 'grass',
#  657: 'Diaper',
#  658: 'humeur',
#  659: 'Egeo',
#  660: 'Oven',
#  661: '458',
#  662: 'GPD',
#  663: 'Humidity',
#  664: 'qui',
#  665: 'amendments',
#  666: '#draislive',
#  667: 'cover',
#  668: 'Blog',
#  669: 'user',
#  670: 'demolished',
#  671: 'sad-just',
#  672: 'W/Joe',
#  673: 'imdb',
#  674: 'Southern',
#  675: '#blocked',
#  676: 'Nieuws',
#  677: '#hack',
#  678: 'Image',
#  679: 'scream',
#  680: 'COMMENT',
#  681: 'response',
#  682: 'Aka',
#  683: 'ily',
#  684: 'TAE',
#  685: 'MGBSFL',
#  686: 'An',
#  687: 'drive-by',
#  688: 'astonishing',
#  689: 'folks',
#  690: 'SQL',
#  691: 'conduct',
#  692: '#Sustainability',
#  693: 'eyeliner',
#  694: 'london',
#  695: '#Arkansas',
#  696: 'Downey',
#  697: 'citizenry',
#  698: '#HIPAA',
#  699: '#StingVsTripleH',
#  700: '#hunger',
#  701: 'dawg',
#  702: '#resume',
#  703: 'repeat',
#  704: 'clock',
#  705: '-RJJ”',
#  706: 'Johannesburg',
#  707: 'dance',
#  708: 'OOC',
#  709: '#SQLi',
#  710: 'Tonight-Local',
#  711: 'sparri',
#  712: 'choices',
#  713: '3lelaki',
#  714: 'Nichkhun',
#  715: 'Intellectual',
#  716: '`MAMA`',
#  717: 'WEIRD',
#  718: 'dele',
#  719: 'Uve',
#  720: 'Lls',
#  721: 'Switzerland',
#  722: '9.99',
#  723: 're',
#  724: 'listings',
#  725: '#TheForceAwakens',
#  726: 'watershed',
#  727: 'complex',
#  728: 'Hamm',
#  729: 'and',
#  730: '#Retweet',
#  731: 'MovieSoonFor',
#  732: 'Draft',
#  733: 'furniture',
#  734: 'SKE48',
#  735: 'Cachupas',
#  736: 'nombre',
#  737: 'GA',
#  738: 'Bawana',
#  739: '02:36',
#  740: 'JAN',
#  741: 'Furukawa',
#  742: 'bias',
#  743: 'meant',
#  744: 'Interviews',
#  745: 'declassification',
#  746: 'sundays',
#  747: 'NE',
#  748: 'Leche',
#  749: 'seeing',
#  750: 'ris',
#  751: 'Lessons',
#  752: '#6',
#  753: 'entails',
#  754: 'banned',
#  755: 'Yahoo',
#  756: 'custom',
#  757: 'Dani',
#  758: 'moonlight',
#  759: 'SKY',
#  760: 'chelsea',
#  761: 'potatoes',
#  762: '#PassionParties',
#  763: 'Kiran',
#  764: 'wash',
#  765: 'ftw',
#  766: 'manija',
#  767: "O'clock.",
#  768: 'ngiler',
#  769: 'Earle',
#  770: '#useless',
#  771: 'Climbing',
#  772: 'ECPC',
#  773: 'aming',
#  774: 'VW',
#  775: 'popularity',
#  776: 'kaibigan',
#  777: 'Rab',
#  778: 'Cocaine',
#  779: 'kc',
#  780: 'Score',
#  781: 'Sus',
#  782: '#HnF',
#  783: 'Samui',
#  784: 'Brigade',
#  785: ',?',
#  786: 'Voxel8',
#  787: 'Teenage',
#  788: 'Gilberto',
#  789: 'anxiety',
#  790: 'stared',
#  791: 'drive',
#  792: '#Cabinet',
#  793: 'Pokemon',
#  794: 'frees',
#  795: 'sana',
#  796: 'ibe',
#  797: 'Barometric',
#  798: 'Clear',
#  799: 'Mukherjee',
#  800: '13th',
#  801: 'ECS',
#  802: 'AT&amp;T',
#  803: 'Mas',
#  804: 'Kshs',
#  805: 'maintenant',
#  806: 'BROTHER',
#  807: 'FEBRUARY',
#  808: 'Shoutout',
#  809: 'recruits',
#  810: 'woot',
#  811: 'moves',
#  812: '3/5',
#  813: 'prank',
#  814: 'Logging',
#  815: '#STLCards',
#  816: 'LiLo',
#  817: 'Ashutosh',
#  818: 'Pre',
#  819: 'covered',
#  820: '#DataBreachhttp',
#  821: 'beans',
#  822: 'Buford',
#  823: 'helmet',
#  824: 'Paalam',
#  825: 'three',
#  826: 'wertheim',
#  827: 'Little',
#  828: '#Spurs',
#  829: 'quando',
#  830: '#premierleague',
#  831: 'label',
#  832: 'DAY6',
#  833: 'syang',
#  834: 'and/fatt',
#  835: 'phil',
#  836: 'pendaftaran',
#  837: '#TeenWolf',
#  838: 'cobalah',
#  839: 'scarey',
#  840: 'Tenshi',
#  841: 'beberkan',
#  842: 'Inception',
#  843: 'brazos',
#  844: 'EDITION',
#  845: 'Correct',
#  846: 'clutch',
#  847: 'temp',
#  848: 'punchline',
#  849: 'latimes',
#  850: 'Coinbase',
#  851: 'Favre',
#  852: 'Filipino',
#  853: 'blmd',
#  854: 'PangakoSayo',
#  855: 'possibly',
#  856: 'Rain',
#  857: 'havoc',
#  858: 'PDT',
#  859: 'avoided',
#  860: 'sobrang',
#  861: 'CONSOLIDA',
#  862: '25%',
#  863: 'Zennie62',
#  864: 'Dirk',
#  865: 'Savoirfaire',
#  866: 'Renault',
#  867: 'sejak',
#  868: 'sheep',
#  869: 'lingerie',
#  870: 'machines',
#  871: 'Progress',
#  872: 'Boards',
#  873: 'Tip',
#  874: '#Beach',
#  875: 'Came',
#  876: 'ASISTEN',
#  877: '#softballready',
#  878: 'Catherine',
#  879: 'entrain',
#  880: '#911',
#  881: 'longg',
#  882: 'yapping',
#  883: '#severewx',
#  884: 'Funny',
#  885: '#Mumbai',
#  886: 'destiny',
#  887: 'IE',
#  888: 'rad',
#  889: 'complain',
#  890: 'Rican',
#  891: 'Hopeful',
#  892: 'sorbet',
#  893: 'yours',
#  894: 'Teachers',
#  895: 'enters',
#  896: 'lambrini',
#  897: 'flipping',
#  898: 'stunts',
#  899: 'bikinis',
#  900: 'solutions',
#  901: 'migranti',
#  902: 'Whiteside',
#  903: 'kang',
#  904: 'masamang',
#  905: 'Hydrating',
#  906: 'papasok',
#  907: 'Story',
#  908: '1dlovesoned',
#  909: 'Atwater',
#  910: 'Laughlin',
#  911: 'Pavonia',
#  912: 'Exchange',
#  913: 'Juicy',
#  914: 'akomg',
#  915: 'tally',
#  916: 'LGBT',
#  917: 'two',
#  918: 'DING',
#  919: 'are',
#  920: 'Feet',
#  921: 'Theeeeeeeeeee',
#  922: 'Donating',
#  923: 'chewables',
#  924: 'MOTD',
#  925: 'US/Eastern)',
#  926: "Didn't",
#  927: 'grater',
#  928: '20:10',
#  929: '+3',
#  930: 'Fasting',
#  931: 'turn',
#  932: 'convention',
#  933: 'PIC',
#  934: 'Megan',
#  935: 'INVITATION',
#  936: 'lose',
#  937: '#TGIBF',
#  938: 'Camino',
#  939: 'K-POP',
#  940: 'Bordeaux',
#  941: 'Mancini',
#  942: 'alejo',
#  943: '03:20',
#  944: '#tweetbatt',
#  945: 'probs',
#  946: 'Roberto',
#  947: '#Touchnote',
#  948: 'Massive',
#  949: 'PIT',
#  950: 'pill',
#  951: 'Dun',
#  952: 'reset',
#  953: 'Exposure',
#  954: 'Pulling',
#  955: '#readit',
#  956: "Hahaha'",
#  957: 'block',
#  958: 'los',
#  959: 'rode',
#  960: '501',
#  961: 'registered',
#  962: 'Unarmed',
#  963: 'wtf',
#  964: 'Montgomery',
#  965: 'nutshell',
#  966: 'iffy',
#  967: 'songz',
#  968: 'sunday',
#  969: 'Kainis',
#  970: 'john@thelittleaussiebakery',
#  971: 'needing',
#  972: 'perfom',
#  973: 'TEAM',
#  974: '#WonderGirls',
#  975: 'Dame',
#  976: '#growinguptoofast',
#  977: 'eyes*',
#  978: '#giveaways',
#  979: 'Omaha',
#  980: 'BlackBerry',
#  981: '#InOMN10',
#  982: 'Parti',
#  983: 'Strongest',
#  984: 'Dec-28-2014',
#  985: 'est',
#  986: 'smiley',
#  987: '#COYR',
#  988: 'chasin',
#  989: '#Salamanca',
#  990: 'NIGHT',
#  991: 'Tour',
#  992: 'Aaaaah',
#  993: 'tryin',
#  994: 'bash',
#  995: 'ewan',
#  996: 'Hold',
#  997: '#Rachel',
#  998: 'Andrew',
#  999: 'MAIL',
#  ...}

# %% [markdown]
# The next additional functions will help you to create the mapping between tokens and ids for a sentence.

# %%
def words2idxs(tokens_list):
    return [token2idx[word] for word in tokens_list]

def tags2idxs(tags_list):
    return [tag2idx[tag] for tag in tags_list]

def idxs2words(idxs):
    return [idx2token[idx] for idx in idxs]

def idxs2tags(idxs):
    return [idx2tag[idx] for idx in idxs]

# %% [markdown]
# ### Generate batches
#
# Neural Networks are usually trained with batches. It means that weight updates of the network are based on several sequences at every single time. The tricky part is that all sequences within a batch need to have the same length. So we will pad them with a special `<PAD>` token. It is also a good practice to provide RNN with sequence lengths, so it can skip computations for padding parts. We provide the batching function *batches_generator* readily available for you to save time.

# %%
def batches_generator(batch_size, tokens, tags,
                      shuffle=True, allow_smaller_last_batch=True):
    """Generates padded batches of tokens and tags."""
    
    n_samples = len(tokens)
    if shuffle:
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)

    n_batches = n_samples // batch_size
    if allow_smaller_last_batch and n_samples % batch_size:
        n_batches += 1

    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start
        x_list = []
        y_list = []
        max_len_token = 0
        for idx in order[batch_start: batch_end]:
            x_list.append(words2idxs(tokens[idx]))
            y_list.append(tags2idxs(tags[idx]))
            max_len_token = max(max_len_token, len(tags[idx]))
            
        # Fill in the data into numpy nd-arrays filled with padding indices.
        x = np.ones([current_batch_size, max_len_token], dtype=np.int32) * token2idx['<PAD>']
        y = np.ones([current_batch_size, max_len_token], dtype=np.int32) * tag2idx['O']
        lengths = np.zeros(current_batch_size, dtype=np.int32)
        for n in range(current_batch_size):
            utt_len = len(x_list[n])
            x[n, :utt_len] = x_list[n]
            lengths[n] = utt_len
            y[n, :utt_len] = y_list[n]
        yield x, y, lengths

# %% [markdown]
# ## Build a recurrent neural network
#
# This is the most important part of the assignment. Here we will specify the network architecture based on TensorFlow building blocks. It's fun and easy as a lego constructor! __We will create an LSTM network which will produce probability distribution over tags for each token in a sentence. To take into account both right and left contexts of the token, we will use Bi-Directional LSTM (Bi-LSTM).__ Dense layer will be used on top to perform tag classification.

# %%
import tensorflow as tf
import numpy as np

# %%
class BiLSTMModel():
    pass

# %% [markdown]
# __First, we need to create [placeholders](https://www.tensorflow.org/versions/master/api_docs/python/tf/placeholder) to specify what data we are going to feed into the network during the execution time.__  For this task we will need the following placeholders:
#  - *input_batch* — sequences of words (the shape equals to [batch_size, sequence_len]);
#  - *ground_truth_tags* — sequences of tags (the shape equals to [batch_size, sequence_len]);
#  - *lengths* — lengths of not padded sequences (the shape equals to [batch_size]);
#  - *dropout_ph* — dropout keep probability; this placeholder has a predefined value 1;
#  - *learning_rate_ph* — learning rate; we need this placeholder because we want to change the value during training.
#
# It could be noticed that we use *None* in the shapes in the declaration, which means that data of any size can be feeded.
#
# You need to complete the function *declare_placeholders*.

# %%
def declare_placeholders(self):
    """Specifies placeholders for the model."""
    # Placeholders for input and ground truth output.
    self.input_batch = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input_batch') # [batch_size, sequence_len]
    self.ground_truth_tags = tf.placeholder(dtype=tf.int32, shape=[None, None], name='ground_truth_tags')
    
    # Placeholder for lengths of the sequences.
    self.lengths = tf.placeholder(dtype=tf.int32, shape=[None], name='lengths') 
    
    # Placeholder for a dropout keep probability. If we don't feed
    # a value for this placeholder, it will be equal to 1.0.
    self.dropout_ph = tf.placeholder_with_default(tf.cast(1.0, tf.float32), shape=[])
    
    # Placeholder for a learning rate (tf.float32).
    self.learning_rate_ph = tf.placeholder(dtype=tf.float32, shape=[], name='learning_rate_ph')

# %%
BiLSTMModel.__declare_placeholders = classmethod(declare_placeholders)

# %% [markdown]
# Now, let us specify the layers of the neural network. First, we need to perform some __preparatory steps__:
#
# - Create __embeddings matrix__ with [tf.Variable](https://www.tensorflow.org/api_docs/python/tf/Variable). Specify its name (*embeddings_matrix*), type  (*tf.float32*), and __initialize with random values__.
# - Create __forward and backward LSTM cells__. TensorFlow provides a number of RNN cells ready for you. We suggest that you use *LSTMCell*, but you can also experiment with other types, e.g. GRU cells. [This](http://colah.github.io/posts/2015-08-Understanding-LSTMs/) blogpost could be interesting if you want to learn more about the differences.
# - Wrap your cells with [DropoutWrapper](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper). Dropout is an important regularization technique for neural networks. Specify all keep probabilities using the dropout placeholder that we created before.
#
# After that, you can build the computation graph that transforms an input_batch:
#
# - [Look up](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) embeddings for an *input_batch* in the prepared *embedding_matrix*.
# - Pass the embeddings through [Bidirectional Dynamic RNN](https://www.tensorflow.org/api_docs/python/tf/nn/bidirectional_dynamic_rnn) with the specified forward and backward cells. Use the lengths placeholder here to avoid computations for padding tokens inside the RNN.
# - Create a dense layer on top. Its output will be used directly in loss function.
#
# Fill in the code below. In case you need to debug something, the easiest way is to check that tensor shapes of each step match the expected ones.

# %%
def build_layers(self, vocabulary_size, embedding_dim, n_hidden_rnn, n_tags):
    """Specifies bi-LSTM architecture and computes logits for inputs."""
    
    # Create embedding variable (tf.Variable) with dtype tf.float32
    initial_embedding_matrix = np.random.randn(vocabulary_size, embedding_dim) / np.sqrt(embedding_dim)
    embedding_matrix_variable = tf.Variable(initial_value=initial_embedding_matrix, dtype=tf.float32)
    
    # Create RNN cells (for example, tf.nn.rnn_cell.BasicLSTMCell) with n_hidden_rnn number of units 
    # and dropout (tf.nn.rnn_cell.DropoutWrapper), initializing all *_keep_prob with dropout placeholder.
    forward_cell = tf.nn.rnn_cell.DropoutWrapper(cell=tf.nn.rnn_cell.BasicLSTMCell(num_units=n_hidden_rnn),
                                                 input_keep_prob=self.dropout_ph,
                                                 output_keep_prob=self.dropout_ph,
                                                 state_keep_prob=self.dropout_ph)
    
    backward_cell = tf.nn.rnn_cell.DropoutWrapper(cell=tf.nn.rnn_cell.BasicLSTMCell(num_units=n_hidden_rnn),
                                                 input_keep_prob=self.dropout_ph,
                                                 output_keep_prob=self.dropout_ph,
                                                 state_keep_prob=self.dropout_ph)

    # Look up embeddings for self.input_batch (tf.nn.embedding_lookup).
    # Shape: [batch_size, sequence_len, embedding_dim].
    embeddings =  tf.nn.embedding_lookup(params=embedding_matrix_variable, ids=self.input_batch)
    
    # Pass them through Bidirectional Dynamic RNN (tf.nn.bidirectional_dynamic_rnn).
    # Shape: [batch_size, sequence_len, 2 * n_hidden_rnn]. 
    # Also don't forget to initialize sequence_length as self.lengths and dtype as tf.float32.
    (rnn_output_fw, rnn_output_bw), _ =  tf.nn.bidirectional_dynamic_rnn(cell_fw=forward_cell, 
                                                                         cell_bw=backward_cell, 
                                                                         inputs=embeddings, 
                                                                         sequence_length=self.lengths, 
                                                                         dtype=tf.float32)
                                                 
    rnn_output = tf.concat([rnn_output_fw, rnn_output_bw], axis=2)

    # Dense layer on top.
    # Shape: [batch_size, sequence_len, n_tags].   
    self.logits = tf.layers.dense(rnn_output, n_tags, activation=None)

# %%
BiLSTMModel.__build_layers = classmethod(build_layers)

# %% [markdown]
# To compute the actual predictions of the neural network, you need to apply [softmax](https://www.tensorflow.org/api_docs/python/tf/nn/softmax) to the last layer and find the most probable tags with [argmax](https://www.tensorflow.org/api_docs/python/tf/argmax).

# %%
def compute_predictions(self):
    """Transforms logits to probabilities and finds the most probable tags."""
    
    # Create softmax (tf.nn.softmax) function
    softmax_output = tf.nn.softmax(logits=self.logits)
    
    # Use argmax (tf.argmax) to get the most probable tags
    # Don't forget to set axis=-1
    # otherwise argmax will be calculated in a wrong way
    self.predictions = tf.argmax(input=softmax_output, axis=-1)

# %%
BiLSTMModel.__compute_predictions = classmethod(compute_predictions)

# %% [markdown]
# During training we do not need predictions of the network, but we need a loss function. We will use [cross-entropy loss](http://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html#cross-entropy), efficiently implemented in TF as
# [cross entropy with logits](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits_v2). Note that it should be applied to logits of the model (not to softmax probabilities!). Also note,  that we do not want to take into account loss terms coming from `<PAD>` tokens. So we need to mask them out, before computing [mean](https://www.tensorflow.org/api_docs/python/tf/reduce_mean).

# %%
def compute_loss(self, n_tags, PAD_index):
    """Computes masked cross-entopy loss with logits."""
    
    # Create cross entropy function function (tf.nn.softmax_cross_entropy_with_logits_v2)
    ground_truth_tags_one_hot = tf.one_hot(self.ground_truth_tags, n_tags)
    loss_tensor = tf.nn.softmax_cross_entropy_with_logits_v2(labels=ground_truth_tags_one_hot, logits=self.logits)
    
    mask = tf.cast(tf.not_equal(self.input_batch, PAD_index), tf.float32)
    # Create loss function which doesn't operate with <PAD> tokens (tf.reduce_mean)
    # Be careful that the argument of tf.reduce_mean should be
    # multiplication of mask and loss_tensor.
    self.loss =  tf.reduce_mean(tf.cast(x=tf.boolean_mask(tensor=loss_tensor, mask=mask), dtype=tf.float32), keepdims=False)

# %%
BiLSTMModel.__compute_loss = classmethod(compute_loss)

# %% [markdown]
# The last thing to specify is how we want to optimize the loss.
# We suggest that you use [Adam](https://www.tensorflow.org/api_docs/python/tf/train/AdamOptimizer) optimizer with a learning rate from the corresponding placeholder.
# You will also need to apply clipping to eliminate exploding gradients. It can be easily done with [clip_by_norm](https://www.tensorflow.org/api_docs/python/tf/clip_by_norm) function.

# %%
def perform_optimization(self):
    """Specifies the optimizer and train_op for the model."""
    
    # Create an optimizer (tf.train.AdamOptimizer)
    self.optimizer =  tf.train.AdamOptimizer(learning_rate=self.learning_rate_ph)
    self.grads_and_vars = self.optimizer.compute_gradients(self.loss)
    
    # Gradient clipping (tf.clip_by_norm) for self.grads_and_vars
    # Pay attention that you need to apply this operation only for gradients 
    # because self.grads_and_vars also contains variables.
    # list comprehension might be useful in this case.
    clip_norm = tf.cast(1.0, tf.float32)
    self.grads_and_vars = [(tf.clip_by_norm(i[0],clip_norm), i[1]) for i in self.grads_and_vars]
    
    self.train_op = self.optimizer.apply_gradients(self.grads_and_vars)

# %%
BiLSTMModel.__perform_optimization = classmethod(perform_optimization)

# %% [markdown]
# Congratulations! You have specified all the parts of your network. You may have noticed, that we didn't deal with any real data yet, so what you have written is just recipes on how the network should function.
# Now we will put them to the constructor of our Bi-LSTM class to use it in the next section.

# %%
def init_model(self, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index):
    self.__declare_placeholders()
    self.__build_layers(vocabulary_size, embedding_dim, n_hidden_rnn, n_tags)
    self.__compute_predictions()
    self.__compute_loss(n_tags, PAD_index)
    self.__perform_optimization()

# %%
BiLSTMModel.__init__ = classmethod(init_model)

# %% [markdown]
# ## Train the network and predict tags

# %% [markdown]
# [Session.run](https://www.tensorflow.org/api_docs/python/tf/Session#run) is a point which initiates computations in the graph that we have defined. To train the network, we need to compute *self.train_op*, which was declared in *perform_optimization*. To predict tags, we just need to compute *self.predictions*. Anyway, we need to feed actual data through the placeholders that we defined before.

# %%
def train_on_batch(self, session, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability):
    feed_dict = {self.input_batch: x_batch,
                 self.ground_truth_tags: y_batch,
                 self.learning_rate_ph: learning_rate,
                 self.dropout_ph: dropout_keep_probability,
                 self.lengths: lengths}
    session.run(self.train_op, feed_dict=feed_dict)

# %%
BiLSTMModel.train_on_batch = classmethod(train_on_batch)

# %% [markdown]
# Implement the function *predict_for_batch* by initializing *feed_dict* with input *x_batch* and *lengths* and running the *session* for *self.predictions*.

# %%
def predict_for_batch(self, session, x_batch, lengths):
    feed_dict = {self.input_batch: x_batch, self.lengths: lengths}
    predictions = session.run(self.predictions, feed_dict=feed_dict)
    return predictions

# %%
BiLSTMModel.predict_for_batch = classmethod(predict_for_batch)

# %% [markdown]
# We finished with necessary methods of our BiLSTMModel model and almost ready to start experimenting.
#
# ### Evaluation
# To simplify the evaluation process we provide two functions for you:
#  - *predict_tags*: uses a model to get predictions and transforms indices to tokens and tags;
#  - *eval_conll*: calculates precision, recall and F1 for the results.

# %%
from evaluation import precision_recall_f1

# %%
def predict_tags(model, session, token_idxs_batch, lengths):
    """Performs predictions and transforms indices to tokens and tags."""
    
    tag_idxs_batch = model.predict_for_batch(session, token_idxs_batch, lengths)
    
    tags_batch, tokens_batch = [], []
    for tag_idxs, token_idxs in zip(tag_idxs_batch, token_idxs_batch):
        tags, tokens = [], []
        for tag_idx, token_idx in zip(tag_idxs, token_idxs):
            tags.append(idx2tag[tag_idx])
            tokens.append(idx2token[token_idx])
        tags_batch.append(tags)
        tokens_batch.append(tokens)
    return tags_batch, tokens_batch
    
    
def eval_conll(model, session, tokens, tags, short_report=True):
    """Computes NER quality measures using CONLL shared task script."""
    
    y_true, y_pred = [], []
    for x_batch, y_batch, lengths in batches_generator(1, tokens, tags):
        tags_batch, tokens_batch = predict_tags(model, session, x_batch, lengths)
        if len(x_batch[0]) != len(tags_batch[0]):
            raise Exception("Incorrect length of prediction for the input, "
                            "expected length: %i, got: %i" % (len(x_batch[0]), len(tags_batch[0])))
        predicted_tags = []
        ground_truth_tags = []
        for gt_tag_idx, pred_tag, token in zip(y_batch[0], tags_batch[0], tokens_batch[0]): 
            if token != '<PAD>':
                ground_truth_tags.append(idx2tag[gt_tag_idx])
                predicted_tags.append(pred_tag)

        # We extend every prediction and ground truth sequence with 'O' tag
        # to indicate a possible end of entity.
        y_true.extend(ground_truth_tags + ['O'])
        y_pred.extend(predicted_tags + ['O'])
        
    results = precision_recall_f1(y_true, y_pred, print_results=True, short_report=short_report)
    return results

# %% [markdown]
# ## Run your experiment

# %% [markdown]
# Create *BiLSTMModel* model with the following parameters:
#  - *vocabulary_size* — number of tokens;
#  - *n_tags* — number of tags;
#  - *embedding_dim* — dimension of embeddings, recommended value: 200;
#  - *n_hidden_rnn* — size of hidden layers for RNN, recommended value: 200;
#  - *PAD_index* — an index of the padding token (`<PAD>`).
#
# Set hyperparameters. You might want to start with the following recommended values:
# - *batch_size*: 32;
# - 4 epochs;
# - starting value of *learning_rate*: 0.005
# - *learning_rate_decay*: a square root of 2;
# - *dropout_keep_probability*: try several values: 0.1, 0.5, 0.9.
#
# However, feel free to conduct more experiments to tune hyperparameters and earn extra points for the assignment.

# %%
tf.reset_default_graph()

model = BiLSTMModel(n_tags=len(tag2idx), vocabulary_size=len(token2idx), embedding_dim=200, n_hidden_rnn=200, PAD_index=token2idx['<PAD>'])

batch_size = 32
n_epochs = 4
learning_rate = 0.005
learning_rate_decay = np.sqrt(2)
dropout_keep_probability = 0.5
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# __If got an error *"Tensor conversion requested dtype float64 for Tensor with dtype float32"* in this point, check if there are variables without dtype initialised. Set the value of dtype equals to *tf.float32* for such variables.__

# %% [markdown]
# Finally, we are ready to run the training!

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

print('Start training... \n')
for epoch in range(n_epochs):
    # For each epoch evaluate the model on train and validation data
    print('-' * 20 + ' Epoch {} '.format(epoch+1) + 'of {} '.format(n_epochs) + '-' * 20)
    print('Train data evaluation:')
    eval_conll(model, sess, train_tokens, train_tags, short_report=True)
    print('Validation data evaluation:')
    eval_conll(model, sess, validation_tokens, validation_tags, short_report=True)
    # Train the model
    for x_batch, y_batch, lengths in batches_generator(batch_size, train_tokens, train_tags):
        model.train_on_batch(sess, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability)
    # Decaying the learning rate
    learning_rate = learning_rate / learning_rate_decay
print('...training finished.')
# Out:
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 72569 phrases; correct: 153.
#
# precision:  0.21%; recall:  3.41%; F1:  0.40
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 8797 phrases; correct: 15.
#
# precision:  0.17%; recall:  2.79%; F1:  0.32
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 2957 phrases; correct: 654.
#
# precision:  22.12%; recall:  14.57%; F1:  17.57
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 258 phrases; correct: 61.
#
# precision:  23.64%; recall:  11.36%; F1:  15.35
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4536 phrases; correct: 1830.
#
# precision:  40.34%; recall:  40.77%; F1:  40.55
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 330 phrases; correct: 116.
#
# precision:  35.15%; recall:  21.60%; F1:  26.76
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4923 phrases; correct: 2024.
#
# precision:  41.11%; recall:  45.09%; F1:  43.01
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 413 phrases; correct: 125.
#
# precision:  30.27%; recall:  23.28%; F1:  26.32
#
# ...training finished.

# %% [markdown]
# Now let us see full quality reports for the final model on train, validation, and test sets. To give you a hint whether you have implemented everything correctly, you might expect F-score about 40% on the validation set.
#
# **The output of the cell below (as well as the output of all the other cells) should be present in the notebook for peer2peer review!**

# %%
print('-' * 20 + ' Train set quality: ' + '-' * 20)
train_results = eval_conll(model, sess, train_tokens, train_tags, short_report=False)

print('-' * 20 + ' Validation set quality: ' + '-' * 20)
validation_results = eval_conll(model, sess, validation_tokens, validation_tags, short_report=False)

print('-' * 20 + ' Test set quality: ' + '-' * 20)
test_results = eval_conll(model, sess, test_tokens, test_tags, short_report=False)
# Out:
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4463 phrases; correct: 2510.
#
# precision:  56.24%; recall:  55.91%; F1:  56.08
#
# 	     company: precision:   86.07%; recall:   70.14%; F1:   77.29; predicted:   524
#
# 	    facility: precision:   45.38%; recall:   73.57%; F1:   56.14; predicted:   509
#
# 	     geo-loc: precision:   80.17%; recall:   85.24%; F1:   82.63; predicted:  1059
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:    9.68%; recall:    2.59%; F1:    4.08; predicted:    62
#
# 	       other: precision:    5.66%; recall:    3.70%; F1:    4.47; predicted:   495
#
# 	      person: precision:   55.49%; recall:   91.20%; F1:   69.00; predicted:  1456
#
# 	     product: precision:   30.68%; recall:   24.21%; F1:   27.07; predicted:   251
#
# 	  sportsteam: precision:   56.07%; recall:   27.65%; F1:   37.04; predicted:   107
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 388 phrases; correct: 149.
#
# precision:  38.40%; recall:  27.75%; F1:  32.22
#
# 	     company: precision:   72.58%; recall:   43.27%; F1:   54.22; predicted:    62
#
# 	    facility: precision:   20.34%; recall:   35.29%; F1:   25.81; predicted:    59
#
# 	     geo-loc: precision:   68.83%; recall:   46.90%; F1:   55.79; predicted:    77
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    10
#
# 	       other: precision:    1.96%; recall:    1.23%; F1:    1.52; predicted:    51
#
# 	      person: precision:   35.00%; recall:   31.25%; F1:   33.02; predicted:   100
#
# 	     product: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    22
#
# 	  sportsteam: precision:   42.86%; recall:   15.00%; F1:   22.22; predicted:     7
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 440 phrases; correct: 181.
#
# precision:  41.14%; recall:  29.97%; F1:  34.67
#
# 	     company: precision:   77.14%; recall:   32.14%; F1:   45.38; predicted:    35
#
# 	    facility: precision:   27.63%; recall:   44.68%; F1:   34.15; predicted:    76
#
# 	     geo-loc: precision:   74.76%; recall:   46.67%; F1:   57.46; predicted:   103
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     8
#
# 	       other: precision:    5.41%; recall:    3.88%; F1:    4.52; predicted:    74
#
# 	      person: precision:   45.28%; recall:   46.15%; F1:   45.71; predicted:   106
#
# 	     product: precision:    3.45%; recall:    3.57%; F1:    3.51; predicted:    29
#
# 	  sportsteam: precision:   33.33%; recall:    9.68%; F1:   15.00; predicted:     9
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0

# %% [markdown]
# ### Conclusions
#
# Could we say that our model is state of the art and the results are acceptable for the task? Definately, we can say so. Nowadays, Bi-LSTM is one of the state of the art approaches for solving NER problem and it outperforms other classical methods. Despite the fact that we used small training corpora (in comparison with usual sizes of corpora in Deep Learning), our results are quite good. In addition, in this task there are many possible named entities and for some of them we have only several dozens of trainig examples, which is definately small. However, the implemented model outperforms classical CRFs for this task. Even better results could be obtained by some combinations of several types of methods, e.g. see [this](https://arxiv.org/abs/1603.01354) paper if you are interested.
